# %% [markdown]
# <h1 style="text-align: center; font-size: 36px; color: teal">GPT Prompt Notes</h1>

# %% [markdown]
# # MY NOTES
#
# ---

# %% [markdown]
# <h3 style="color:purple">Utilities</h3>
#
# 1. Can you write me a python code to do all that myself with comments throughout?
# 2. Give me the output file and give me the full code block with that update now to run myself.
# 3. Can you learn this documentation and tell me how to get started < link >
# 4. Help me clean, analyze, and potentially merge this NFL data. Start by loading it into a dataframe and telling me about the columns, rows, and data in general.

# %% [markdown]
# <h3 style="color:purple">Custom Instructions</h3>
#
# 1. I am a software engineer who primarily uses Python. I often use ChatGPT to help me code a variety of projects, such as Machine Learning and Trading Algorithms. I also often use ChatGPT to help me analyze and perform deep analysis on my datasets about sports.
#
# 2. Whenever you are coding something, provide me all the snippets in full with comments throughout.
#
#
# - Respond in a professional tone
# - Deep dive into the subjects and concepts
# - Be straight to the point
# - Do precisely what the user asks and including the specific tasks requested and any specific length/programming language/etc requested by the user
# - Give full code blocks as examples when helping with software related tasks
# - At the end of every response put the footer "Morpheus" like it's your name

# %% [markdown]
# <h3 style="color:purple">Generating Reports</h3>
#
# 1. Go through our full conversation and then generate me a report of each section and the findings. Include visulizations and code snippets.
# 2. Please include sections for every question and response.

# %% [markdown]
# <h3 style="color:purple">Machine Learning</h3>
#
# **MASTER PROMPT: You are a data analyst and machine learning expert. You are going to help me analyze data about the NFL that I have collected that we will be later using for general and deep analysis and in predictive modeling. As we go through, please save our steps to a notebook for me to download and run myself after each step - including the questions, answers, code, visualizations, etc. I want line-by-line what we do - no placeholders.**
#
# 1. You are a data analyst and machine learning expert. You are going to help me analyze and clean data about NFL that I have collected that we will be later using for general and deep analysis and in predictive modeling.
#
# 2. Can you do some exploratory analysis and learn this data?
#
# 3. Can you do some descriptive statistics, and maybe make some variables to use in future machine learning models?
#
# 4. Explore the data deeply and tell me some trends that I may not be able to see with the naked eye.
#
# 5. Can you identify important features, create visualizations, and make suggestions on potential analyses or models?
#
# 6. Analyze all the datasets and find me 5 surprising correlations. Maybe visualize some of them here if the analysis fits. Output as many insights as you can.
#
# 7. Draw and visualize 6 insights that would be relevant and helpful to someone betting on the outcome of future fight outcomes. Both the winners of fights, methods of finish, and time of finish.
#
# 8. Can you suggest things to further dig into and additional data that could be useful?
#
# 9. Find me some deeper trends in this data related to ... ?
#
# 10. What kind of modeling can I do with all this data to help me predict ... ?
#
# 11. You are a machine learning and data science expert. You are going to help me analyze my data and then write my own models with it.
#
# 12. I want you to become an expert on different machine learning models and how they can be effective in sports. Then you are going to help me build some of my own model (TRAINING).
#
# 13. I have gathered a ton of data, including fight-by-fight statistics for every UFC event, fighter information such as physical attributes, method of victories, and hometown/association. Basically anything you can think of, I have.
#
# 14. What kind of modeling can I do with all this data to help me predict fights? What kinds of things might be worth comparing and digging deeper into with analytics?
#
# 15. I am looking to build a sports model of some sort to predict UFC fights. Can you learn about Monte Carlo simulations in Python and help me construct my first basic one? I have a lot of programming experience and data collected.
#
# 16. Set up a machine learning pipeline using sklearn to create and compare 3 machine learning models that can predict the rentals target variable of the bike-share dataframe. Determine based on column names which columns are relevant to put into the model and what features to transform and engineer. Evaluate the results using r2 and mse.

# %% [markdown]
# <h3 style="color:purple">Making Predictions</h3>
#
# 1. Using your knowledge of both of them from these datasets, make a prediction on a future fight between (fighter 1) and (fighter 2)
#
# 2. Now please predict the outcome of a future fight between these two fighters <> <> based on these features using a regression (decision tree, monte carlo?) model.
#
# 3. Can you now give me all of what we have discussed in a notebook to download, including the code, visualizations, analysis, and descriptive headings/subheadings throughout?
#
# 4. Can you now give me a notebook to download and run myself of everything we did in this conversation, including the code, analysis, visualizations, comments and descriptive headings/subheadings throughout? Make sure every question and response is has a cell. I want every question and answer inside the notebook from the beginning of our conversation.

# %% [markdown]
# # GENERAL TIPS
#
# ---

# %% [markdown]
# <h3 style="color:purple">Building GPTs the Right Way</h3>
#
# ##### https://www.youtube.com/watch?v=Ah-BO5A8On8&ab_channel=SkillLeapAI
#
# **1. Expand Domain Knowledge:** Continuously update and deepen knowledge in the specified domain, keeping abreast of the latest developments, trends, and innovations.
#
# **2. Simplify Complex Concepts:** Break down and clearly explain complex concepts in the chosen field, making them understandable to both experts and laypersons.
#
# **3. Analyze Real-World Applications:** Provide analyses of case studies or real-world examples, highlighting successes, challenges, and key takeaways.
#
# **4. Address Ethical and Social Implications:** Integrate discussions on ethical considerations, societal impacts, and responsible practices relevant to the field.
#
# **5. Recommend Tools and Resources:** Suggest appropriate tools, resources, and learning materials tailored to various expertise levels within the field.
#
# **6. Industry-Specific Insights:** Deliver insights on applying specialized knowledge in practical, industry-specific contexts, including business or other professional settings.
#
# **7. Forecast Future Trends:** Offer predictions or analyses on future developments and trends in the field and their potential implications.
#
# **8. Interactive Learning and Engagement:** Create interactive learning experiences, such as quizzes, scenarios, or exercises, to engage users in the subject matter.
#
# **9. Guide Project Development:** Provide guidance on conceptualizing, planning, and executing projects relevant to the field, including goal setting and methodology.
#
# **10. Ask for Clarifying Questions:** When faced with queries that lack detail, ask clarifying questions to ensure that the responses are accurate and tailored to the user's needs.
#
# **11. Use Custom Knowledge Base:** Always refer to the custom knowledge base first, before providing a response.
#
# **12. Up-to-Date Information:** Browse the web to provide up-to-date information.
#
# **13. Specialized Knowledge Areas:** Focus on providing in-depth, accurate information in specific areas such as technology, history, or healthcare.
#
# **14. Language Skills Enhancement:** Improve understanding and response capabilities for non-standard dialects, slang, and multiple languages.
#
# **15. Interactive Learning Prompts:** Guide users through interactive learning experiences in various fields.
#
# **16. Mental Health Support:** Offer empathetic responses for mental health topics, guiding users to professional resources.
#
# **17. Customized Humor Style:** Incorporate a unique sense of humor into responses.
#
# **18. Enhanced Creativity for Brainstorming:** Assist in creative brainstorming, generating innovative ideas and solutions.
#
# **19. Dedicated Research Assistant Mode:** Act as a research assistant, proficient in compiling and presenting information on complex topics.
#
# **20. Personalized Fitness and Nutrition Advice:** Provide tailored fitness and nutrition advice based on individual user goals and preferences.
#
# These instructions are designed to enhance the functionality and specificity of GPTs for various applications and user interactions.

# %% [markdown]
# <h3 style="color:purple">Data Science Website Cheat Sheet</h3>
#
#
# The PDF document titled "ChatGPT for Data Science Cheat Sheet" contains the following sections and bullet points:
#
# 1. **Ideas**
#    - Dataset Suggestion: Example of asking ChatGPT for relevant datasets for a predictive model for image classifiers.
#    - Suggest Resources: Example of asking ChatGPT for resources to learn about deep learning.
#    - AB Testing: Example of asking ChatGPT to design an A/B test for a case study.
#    - Career Coaching: Example of asking ChatGPT for advice on transitioning to a data engineer role from a management background.
#
# 2. **Coding**
#    - Train Regression Model: Example of asking ChatGPT to write Python code for a machine learning model that predicts speed.
#    - Hyperparameter Tuning: Example of asking ChatGPT to write Python code to tune hyperparameters for a logistic regression model.
#    - Unit Test: Example of asking ChatGPT to write a unit test for a train function.
#    - Code Explanation: Example of asking ChatGPT to explain a code snippet.
#    - Optimize Code: Example of asking ChatGPT to improve the time complexity of a code snippet.
#
# 3. **SQL**
#    - SQL Formatting: Example of asking ChatGPT to format SQL code and convert all reserved keywords to uppercase.
#    - Translate Between DBMS: Example of asking ChatGPT for the MySQL equivalent of PostgreSQL's DATE_TRUNC.
#    - Calculate Average: Example of asking ChatGPT to write SQL code to calculate an average temperature.
#    - Calculate Runway: Example of asking ChatGPT to write SQL to calculate runway.
#
# 4. **Spreadsheets**
#    - Spreadsheets Formula: Example of asking ChatGPT to create a spreadsheet formula to calculate the sum of cells B1 to B20.
#
# 5. **Data Analysis**
#    - Generate Data: Example of asking ChatGPT to generate fake data with 100 rows and 4 columns.
#    - Data Cleaning: Example of asking ChatGPT to write Python code for data cleaning for a text classification dataset.
#    - Data Exploration: Example of asking ChatGPT to write R code for data visualization and exploration for a dataset.
#    - Data Visualization: Example of asking ChatGPT to create a matplotlib bar chart of subject vs. grade.
#
# 6. **Machine Learning Research**
#    - Explain the Concept: Example of asking ChatGPT to explain the t-test to an undergraduate as a data science instructor.
#    - Stakeholders: Example of asking ChatGPT for tips on explaining data science reports to a business stakeholder.
#    - Summarize the paper: Example of asking ChatGPT to summarize a paper in simple terms in one paragraph.
#    - Writing Blog: Example of asking ChatGPT to write an outline for a blog on "Python lists".
#    - Research History: Example of asking ChatGPT to research the history of the graph neural network.
#
# 7. **Dummy Data**
#    - Generate the dummy data: Example of asking ChatGPT to generate dummy data for use as placeholders in a spreadsheet.
#    - Tips: Example of asking ChatGPT for tips on how to improve the efficiency of a spreadsheet.
#
# 8. **Imbalance Data**
#    - Oversample and/or Undersample: Example of asking ChatGPT to handle an imbalanced dataset with a target column in Python.
#    - Explain the Model: Example of asking ChatGPT to write Python code to explain the output of a LightGBM model using a series of plots with Shap.
#
# The document ends with a note to subscribe to KDnuggets News and visit KDnuggets.com for more cheat sheets and additional learning resources. The cheat sheet was created by Abid Ali Awan in 2023.

# %% [markdown]
# <h3 style="color:purple">Machine Learning Website Cheat Sheet</h3>
#
# The PDF document titled "Machine Learning with ChatGPT Cheat Sheet" contains the following sections and bullet points:
#
# 1. **Project Planning**
#    - Keyword Methodology: Example of asking ChatGPT to write a summary of a machine learning project idea using specific keywords.
#    - Data Description Methodology: Example of asking ChatGPT to list the steps to develop an end-to-end customer classification project using a specific dataset.
#
# 2. **Experiment Tracking**
#    - Suggestion: Example of asking ChatGPT to suggest popular tools for experiment tracking in machine learning projects.
#    - Experiment Tracking with MLFlow: Example of asking ChatGPT to write Python code using MLflow for experiment tracking with logistic regression.
#    - Tracking Code, Model, and Dataset: Example of asking ChatGPT to explain how to use DVC to track code, model, and dataset in a machine learning project.
#
# 3. **Feature Engineering**
#    - General Method: Example of asking ChatGPT to write Python code to perform feature engineering.
#    - Feature Engineering with Columns: Example of asking ChatGPT to write Python code for feature engineering using specific columns.
#
# 4. **Data Preprocessing**
#    - General: Example of asking ChatGPT to write Python code to clean and preprocess a specific dataset.
#    - Data Cleaning: Example of asking ChatGPT to write Python code to handle missing values and outliers or anomalies in the data.
#    - Preprocessing: Example of asking ChatGPT to write Python code to convert categorical variables into numeric variables and scale/normalize the data.
#    - Class Imbalance Issue: Example of asking ChatGPT to address the class imbalance issue by either oversampling the minority class or undersampling the majority class.
#
# 5. **Model Selection**
#    - General: Example of asking ChatGPT to write Python code for model selection, including decision trees, random forests, logistic regression, or support vector machines (SVM).
#    - Training and Testing sets: Example of asking ChatGPT to write Python code to split the dataset into training and testing sets.
#
# 6. **Hyperparameter Tuning**
#    - Model Evaluation: Example of asking ChatGPT to write Python code to perform model evaluation for a logistic regression model using cross-validation and various evaluation metrics.
#    - Hyperparameter Tuning: Example of asking ChatGPT to modify the above code to include hyperparameter tuning and save the best-performing model.
#    - Bayesian Optimization: Example of asking ChatGPT to write Python code to tune hyperparameters using Bayesian optimization.
#
# 7. **MLOps**
#    - Streamlit App: Example of asking ChatGPT to explain how to create a Streamlit web app for a customer classifier in Python and provide a sample code that loads a saved model and feature scaler and makes predictions based on user input.
#    - Model Deployment on Spaces: Example of asking ChatGPT to explain how to deploy a Streamlit app to Hugging Face space without creating a Docker file.
#    - Model Monitoring: Example of asking ChatGPT to explain how to monitor a model on a Hugging Face Streamlit app.
#    - Automation: Example of asking ChatGPT to provide a detailed guide on creating a Continuous Integration and Delivery (CI/CD) pipeline using Python to regularly update the model on Hugging Face with the latest dataset.
#
# 8. **Evaluation Metric**
#    - Suggestion to use Accuracy, F1 Score, and AUC score for model evaluation in the model selection section.
#
# The document ends with a note to subscribe to KDnuggets News and visit KDnuggets.com for more cheat sheets and additional learning resources. The cheat sheet was created by Abid Ali Awan in 2023.

# %% [markdown]
# <h3 style="color:purple">Streamlit Website Cheat Sheet</h3>
#
# The PDF document titled "Streamlit for Machine Learning Cheat Sheet" contains the following sections and bullet points:
#
# 1. **write**: Display pandas DataFrames, errors, dictionaries, interactive visualization, and Keras models. Example code is provided.
#
# 2. **markdown**: Use markdown to display images, text, headings, and everything else. Example code is provided.
#
# 3. **multiselect**: Add multiselect option widget. Example code is provided.
#
# 4. **input_text**: Add single-line text input widget for NLP and ML models. Example code is provided.
#
# 5. **file_uploader**: Upload any type of file using uploader widget. Example code is provided.
#
# 6. **audio**: Add an audio player. Example code is provided.
#
# 7. **sidebar**: Organize your widgets into a collapsible sidebar. Example code is provided.
#
# 8. **tabs**: Organize your widgets into multiple tabs. Example code is provided.
#
# 9. **progress**: Add progress bar. Example code is provided.
#
# 10. **chart**: Display a line, bar, and area chart. Example code is provided.
#
# 11. **map**: Display a map with points on it. Example code is provided.
#
# 12. **metric**: Display displaying KPIs and model performance metrics. Example code is provided.
#
# 13. **plotly_chart**: Display an interactive Plotly chart. Example code is provided.
#
# 14. **button**: Add the button widget. Example code is provided.
#
# 15. **selectbox**: Add dropdown selectbox widget. Example code is provided.
#
# 16. **image**: Display an image or list of images. Example code is provided.
#
# 17. **cache**: A function decorator to memorize function executions. Example code is provided.

# %% [markdown]
# # OTHER INSTRUCTIONS (verbatim)
#
# ---

# %% [markdown]
# <h3 style="color:purple">Bet GPT</h3>
#
#
# Creating a specialized GPT like betGPT involves a series of steps, which include defining the purpose, gathering data, training the model, and testing it. Here's a detailed breakdown of the process:
#
# 1. Defining Purpose and Scope
# Objective: To create betGPT, a specialized version of ChatGPT focused on providing betting tips and insights.
# Scope: The GPT is designed to offer precise betting tips, focusing on player prop bets, team win probabilities, and spread coverages.
# 2. Data Collection and Preparation
# Sources: The model is to use data from specific sources like KPLCTV.com, WFSB.com, WBNG.com, and Dimers.com.
# Data Type: The data includes analytical statistics and historical betting data related to various sports, primarily focusing on the NBA.
# Preparation: Data is cleaned and structured to be suitable for training. This involves organizing stats, outcomes, odds, and other relevant betting information.
# 3. Model Training
# Base Model: Start with a version of OpenAI's ChatGPT.
# Custom Training: The model is then trained with the specific data collected. This includes:
# Statistical Analysis: Training on patterns and trends in sports statistics.
# Betting Insights: Incorporating knowledge about betting odds, spreads, and probabilities.
# Historical Data: Using past games' data for predictive modeling.
# Feedback Loop: Incorporating feedback to refine predictions and advice.
# 4. Custom Instructions and Capabilities
# Instructions: The model is programmed with specific instructions to focus on offering betting tips. It includes:
# Providing specific recommendations on over/under spreads.
# Insights on player prop bets like NBA player rebounds.
# Analysis of team win probabilities and spread coverages.
# Capabilities: The model is equipped with tools to analyze and interpret sports data and betting odds.
# 5. Testing and Refinement
# Performance Testing: The model's predictions and tips are tested for accuracy and relevance.
# User Feedback: Incorporating user feedback to understand the effectiveness and accuracy of the betting advice.
# 6. Deployment and User Interaction
# Deployment: The model is made available for users.
# User Interaction: It interacts with users, offering betting advice, answering questions, and providing analyses.
# 7. Ongoing Maintenance and Updates
# Data Updates: Regular updates with the latest sports statistics and betting odds.
# Model Improvement: Continuous learning from new data and user interactions to improve predictions and advice.
# 8. Ethical and Legal Considerations
# Compliance: Ensuring the advice complies with legal and ethical standards in betting.
# Responsible Use: Encouraging responsible gambling and betting practices among users.
# 9. User Experience Focus
# Engagement: Designed to be engaging and user-friendly.
# Comprehensive Analysis: Providing a detailed, data-driven analysis in a conversational manner.
# Creating betGPT involves a collaborative effort of data scientists, AI experts, sports analysts, and software developers, ensuring that the model is accurate, reliable, and user-friendly.

# %% [markdown]
# <h3 style="color:purple">Example AI Dude</h3>
#
#
# https://www.underdogchance.com/nfl-betting-model/
#
# “You’re going to create an NFL betting model. I’ll educate you about betting and explain the purpose of this model.
#
# First, though, you need to understand the statistics that I’ll present to you. Alright?
#
# Once you grasp them, respond with “OK.”
#
# After I provide all the necessary information, I’ll indicate it by saying “I AM DONE.” You should then reply with “LET’S START.” Following that, I’ll supply you with the statistics, and you’ll make predictions. Sound good?”
